# %%
# lesson2

#Titanic / データ確認フロー

#CSV読み込み
#  train.csv / test.csv

# データ概要確認
# head() → 最初の数行確認
# info() → 列名・型・欠損確認
# describe() → 数値列の統計量確認

# 欠損値確認
# isnull().sum() → 欠損値の把握

# カテゴリ列確認
# value_counts() → ユニーク値の確認

# データ方針決定
# 使用する列の選定
# 欠損補完方法の決定
# 予測目標の設定（生存予測など）

# %%
# Lesson1

# Decision Tree：
# はい／いいえの質問（条件分岐）を順番に繰り返して、
# 最終的な結論（予測値）を出すモデル

# 例：
# Q1: 高い時計を付けている？
# ├─ Yes → お金持ち
# └─ No  → 貧乏

# 機械学習：
# 過去データから「予測に使えるパターン」を学習すること

# fit：
# データからルール・基準・構造を学習する処理
# （Decision Tree なら分岐ルール、Scaler なら平均と分散など）

# transform / predict：
# fit で学習した内容を使って、データを変換・予測する処理
