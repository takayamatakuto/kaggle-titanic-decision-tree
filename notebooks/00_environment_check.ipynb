# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "x": np.arange(10),
    "y": np.random.randn(10)
})

plt.plot(df["x"], df["y"])
plt.show()

# %%
import sys
sys.executable
# Out:
# 'c:\\Users\\ta910\\OneDrive\\ドキュメント\\data_analysis\\.venv\\Scripts\\python.exe'
